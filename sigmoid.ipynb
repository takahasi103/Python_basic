# %% [markdown]
# <a href="https://colab.research.google.com/github/takahasi103/Python_basic/blob/main/sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # シグモイド関数
# 入力値が与えられた場合、シグモイド関数の出力は0から1の範囲になるため、0に近い値は低い確率を、1に近い値は高い確率を表すことができます。そのため、機械学習の分類問題などで確率を表現するために利用されます。

# %% [markdown]
# * 数式
# $$y=\frac{1}{1+e^{-x}}$$

# %%
import numpy as np
import matplotlib.pyplot as plt

e = np.e  # ネイピア数

def sigmoid(x):
    s = 1 / (1 + e**-x)  # シグモイド関数
    return s

x = np.linspace(-5, 5)
y_sig = sigmoid(x)

plt.plot(x, y_sig)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()

# %% [markdown]
# ## ネイピア数
# $$e = 2.71828 18284 59045 23536 02874 71352 …$$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2)
e = np.e  # ネイピア数

y_2 = 2**x  # 比較用
y_e = e**x  # ネイピア数のべき乗
y_3 = 3**x  # 比較用

plt.plot(x, y_2, label="2^x")
plt.plot(x, y_e, label="e^x")
plt.plot(x, y_3, label="3^x")
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()

# %% [markdown]
# ### ネイピア数のべき乗
# * 数式
# $$y=e^x$$
#
# **曲線の傾きが元の関数に近づいていくという性質があります。**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2, 2)
dx = 0.1  # xの微小な変化
e = np.e  # ネイピア数

y_e = e**x  # 元のべき乗の関数
y_de = (e**(x+dx) - e**x) / dx  # yの微小な変化/xの微小な変化

plt.plot(x, y_e, label="e^x")
plt.plot(x, y_de, label="de")
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()
